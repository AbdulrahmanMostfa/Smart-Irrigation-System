# %%
import numpy as np 
import pandas as pd
import pickle

# %%
import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# %%
import warnings
warnings.simplefilter(action='ignore', category=FutureWarning)
warnings.simplefilter(action='ignore', category=UserWarning)
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df=pd.read_csv('Crop_recommendation.csv')
df.head()
# Out:
#     N   P   K  temperature   humidity        ph    rainfall label
# 0  90  42  43    20.879744  82.002744  6.502985  202.935536  rice
# 1  85  58  41    21.770462  80.319644  7.038096  226.655537  rice
# 2  60  55  44    23.004459  82.320763  7.840207  263.964248  rice
# 3  74  35  40    26.491096  80.158363  6.980401  242.864034  rice
# 4  78  42  42    20.130175  81.604873  7.628473  262.717340  rice

# %%
df.describe()
# Out:
#                  N            P            K  temperature     humidity  \
# count  2200.000000  2200.000000  2200.000000  2200.000000  2200.000000
# mean     50.551818    53.362727    48.149091    25.616244    71.481779
# std      36.917334    32.985883    50.647931     5.063749    22.263812
# min       0.000000     5.000000     5.000000     8.825675    14.258040
# 25%      21.000000    28.000000    20.000000    22.769375    60.261953
# 50%      37.000000    51.000000    32.000000    25.598693    80.473146
# 75%      84.250000    68.000000    49.000000    28.561654    89.948771
# max     140.000000   145.000000   205.000000    43.675493    99.981876
#
#                 ph     rainfall
# count  2200.000000  2200.000000
# mean      6.469480   103.463655
# std       0.773938    54.958389
# min       3.504752    20.211267
# 25%       5.971693    64.551686
# 50%       6.425045    94.867624
# 75%       6.923643   124.267508
# max       9.935091   298.560117

# %%
sns.heatmap(df.isnull(),cmap="coolwarm")
plt.show()

# %%
plt.figure(figsize=(12,5))
plt.subplot(1, 2, 1)
# sns.distplot(df_setosa['sepal_length'],kde=True,color='green',bins=20,hist_kws={'alpha':0.3})
sns.distplot(df['temperature'],color="purple",bins=15,hist_kws={'alpha':0.2})
plt.subplot(1, 2, 2)
sns.distplot(df['ph'],color="green",bins=15,hist_kws={'alpha':0.2})

# %%
sns.countplot(y='label',data=df, palette="plasma_r")

# %%
sns.pairplot(df, hue = 'label')

# %%
c=df.label.astype('category')
targets = dict(enumerate(c.cat.categories))
df['target']=c.cat.codes

y=df.target
X=df[['N','P','K','temperature','humidity','ph','rainfall']]

# %%
sns.heatmap(X.corr())

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import MinMaxScaler

X_train, X_test, y_train, y_test = train_test_split(X, y,random_state=1)

scaler = MinMaxScaler()
X_train_scaled = scaler.fit_transform(X_train)

# we must apply the scaling to the test set as well that we are computing for the training set
X_test_scaled = scaler.transform(X_test)

# %%
from sklearn.neighbors import KNeighborsClassifier
knn = KNeighborsClassifier()
knn.fit(X_train_scaled, y_train)
knn.score(X_test_scaled, y_test)
# Out:
# 0.9781818181818182

# %%
from sklearn.metrics import confusion_matrix
mat=confusion_matrix(y_test,knn.predict(X_test_scaled))
df_cm = pd.DataFrame(mat, list(targets.values()), list(targets.values()))
sns.set(font_scale=1.0) # for label size
plt.figure(figsize = (12,8))
sns.heatmap(df_cm, annot=True, annot_kws={"size": 12},cmap="terrain")

# %%
k_range = range(1,11)
scores = []

for k in k_range:
    knn = KNeighborsClassifier(n_neighbors = k)
    knn.fit(X_train_scaled, y_train)
    scores.append(knn.score(X_test_scaled, y_test))

plt.xlabel('k')
plt.ylabel('accuracy')
plt.scatter(k_range, scores)
plt.vlines(k_range,0, scores, linestyle="dashed")
plt.ylim(0.96,0.99)
plt.xticks([i for i in range(1,11)]);

# %%
from sklearn.svm import SVC

svc_linear = SVC(kernel = 'linear').fit(X_train_scaled, y_train)
print("Linear Kernel Accuracy: ",svc_linear.score(X_test_scaled,y_test))

svc_poly = SVC(kernel = 'rbf').fit(X_train_scaled, y_train)
print("Rbf Kernel Accuracy: ", svc_poly.score(X_test_scaled,y_test))

svc_poly = SVC(kernel = 'poly').fit(X_train_scaled, y_train)
print("Poly Kernel Accuracy: ", svc_poly.score(X_test_scaled,y_test))
# Out:
# Linear Kernel Accuracy:  0.9745454545454545
# Rbf Kernel Accuracy:  0.9872727272727273
# Poly Kernel Accuracy:  0.9890909090909091

# %%
from sklearn.metrics import accuracy_score
from sklearn.model_selection import GridSearchCV

parameters = {'C': np.logspace(-3, 2, 6).tolist(), 'gamma': np.logspace(-3, 2, 6).tolist()}
# 'degree': np.arange(0,5,1).tolist(), 'kernel':['linear','rbf','poly']

model = GridSearchCV(estimator = SVC(kernel="linear"), param_grid=parameters, n_jobs=-1, cv=4)
model.fit(X_train, y_train)
# Out:
# GridSearchCV(cv=4, estimator=SVC(kernel='linear'), n_jobs=-1,
#              param_grid={'C': [0.001, 0.01, 0.1, 1.0, 10.0, 100.0],
#                          'gamma': [0.001, 0.01, 0.1, 1.0, 10.0, 100.0]})

# %%
print(model.best_score_ )
print(model.best_params_ )
# Out:
# 0.9866710547967747
# {'C': 1.0, 'gamma': 0.001}

# %%
from sklearn.tree import DecisionTreeClassifier

clf = DecisionTreeClassifier(random_state=42).fit(X_train, y_train)
clf.score(X_test,y_test)
# Out:
# 0.9872727272727273

# %%
plt.figure(figsize=(10,4), dpi=80)
c_features = len(X_train.columns)
plt.barh(range(c_features), clf.feature_importances_)
plt.xlabel("Feature importance")
plt.ylabel("Feature name")
plt.yticks(np.arange(c_features), X_train.columns)
plt.show()

# %%
'''
max depth and n_estimator are important to fine tune otherwise trees will be densely graphed which will be a classic case of overfitting. max_depth=4 and n_estimators=10 gives pretty much satisfying results by making sure model is able to generalize well.
'''

from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(max_depth=4,n_estimators=100,random_state=42).fit(X_train, y_train)

print('RF Accuracy on training set: {:.2f}'.format(clf.score(X_train, y_train)))
print('RF Accuracy on test set: {:.2f}'.format(clf.score(X_test, y_test)))
# Out:
# RF Accuracy on training set: 0.97
# RF Accuracy on test set: 0.97

# %%
from sklearn.ensemble import GradientBoostingClassifier
grad = GradientBoostingClassifier().fit(X_train, y_train)
print('Gradient Boosting accuracy : {}'.format(grad.score(X_test,y_test)))
# Out:
# Gradient Boosting accuracy : 0.9963636363636363

# %%
# save the model to disk
filename = 'model.sav'
pickle.dump(model, open(filename, 'wb'))
pickle.dump(knn,open('model.pkl','wb'))

# %%
# Define simple neural network model
# Keras

from keras.models import Sequential
from keras.layers import Dense
from tensorflow.keras.optimizers import Adam,RMSprop
import tensorflow as tf

model = Sequential()
model.add(Dense(128, input_dim=7, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(22, activation='softmax'))

model.summary()
# Out:
# Model: "sequential_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_12 (Dense)             (None, 128)               1024
# _________________________________________________________________
# dense_13 (Dense)             (None, 128)               16512
# _________________________________________________________________
# dense_14 (Dense)             (None, 64)                8256
# _________________________________________________________________
# dense_15 (Dense)             (None, 22)                1430
# =================================================================
# Total params: 27,222
# Trainable params: 27,222
# Non-trainable params: 0
# _________________________________________________________________

# %%
callback = tf.keras.callbacks.ModelCheckpoint(filepath='best_model.h5',
                                                  monitor='val_acc', mode='max',
                                                 verbose=1)

es = tf.keras.callbacks.EarlyStopping(monitor='loss', patience=5)

# %%
# Compile the Neural network
model.compile(loss='sparse_categorical_crossentropy', optimizer='adam', metrics=['accuracy'])
# Fit to training data
model.fit(X_train, y_train, epochs=100, validation_data=(X_test,y_test),
                    callbacks=[callback , es])
# Out:
# Epoch 1/100
# 52/52 [==============================] - 1s 6ms/step - loss: 0.1396 - accuracy: 0.9479 - val_loss: 0.0886 - val_accuracy: 0.9600
#
# Epoch 00001: saving model to best_model.h5
# Epoch 2/100
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1227 - accuracy: 0.9533 - val_loss: 0.0884 - val_accuracy: 0.9709
#
# Epoch 00002: saving model to best_model.h5
# Epoch 3/100
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0828 - accuracy: 0.9667 - val_loss: 0.0762 - val_accuracy: 0.9818
#
# Epoch 00003: saving model to best_model.h5
# Epoch 4/100
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0901 - accuracy: 0.9667 - val_loss: 0.0950 - val_accuracy: 0.9655
#
# Epoch 00004: saving model to best_model.h5
# Epoch 5/100
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0986 - accuracy: 0.9630 - val_loss: 0.1036 - val_accuracy: 0.9691
#
# Epoch 00005: saving model to best_model.h5
# Epoch 6/100
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1072 - accuracy: 0.9612 - val_loss: 0.1083 - val_accuracy: 0.9709
#
# Epoch 00006: saving model to best_model.h5
# Epoch 7/100
# 52/52 [==============================] - 0s 2ms/step - loss: 0.1141 - accuracy: 0.9558 - val_loss: 0.0798 - val_accuracy: 0.9782
#
# Epoch 00007: saving model to best_model.h5
# Epoch 8/100
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0768 - accuracy: 0.9697 - val_loss: 0.0903 - val_accuracy: 0.9600
#
# Epoch 00008: saving model to best_model.h5
# Epoch 9/100
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0750 - accuracy: 0.9655 - val_loss: 0.0825 - val_accuracy: 0.9691
#
# Epoch 00009: saving model to best_model.h5
# Epoch 10/100
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1030 - accuracy: 0.9606 - val_loss: 0.0723 - val_accuracy: 0.9745
#
# Epoch 00010: saving model to best_model.h5
# Epoch 11/100
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1043 - accuracy: 0.9570 - val_loss: 0.0736 - val_accuracy: 0.9727
#
# Epoch 00011: saving model to best_model.h5
# Epoch 12/100
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0802 - accuracy: 0.9679 - val_loss: 0.0775 - val_accuracy: 0.9745
#
# Epoch 00012: saving model to best_model.h5
# Epoch 13/100
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0667 - accuracy: 0.9715 - val_loss: 0.0829 - val_accuracy: 0.9727
#
# Epoch 00013: saving model to best_model.h5
# Epoch 14/100
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0971 - accuracy: 0.9570 - val_loss: 0.1144 - val_accuracy: 0.9564
#
# Epoch 00014: saving model to best_model.h5
# Epoch 15/100
# 52/52 [==============================] - 0s 3ms/step - loss: 0.1291 - accuracy: 0.9521 - val_loss: 0.1782 - val_accuracy: 0.9491
#
# Epoch 00015: saving model to best_model.h5
# Epoch 16/100
# 52/52 [==============================] - 0s 2ms/step - loss: 0.1516 - accuracy: 0.9503 - val_loss: 0.1377 - val_accuracy: 0.9545
#
# Epoch 00016: saving model to best_model.h5
# Epoch 17/100
# 52/52 [==============================] - 0s 3ms/step - loss: 0.0819 - accuracy: 0.9655 - val_loss: 0.0747 - val_accuracy: 0.9764
#
# Epoch 00017: saving model to best_model.h5
# Epoch 18/100
# 52/52 [==============================] - 0s 2ms/step - loss: 0.0711 - accuracy: 0.9703 - val_loss: 0.0659 - val_accuracy: 0.9800
#
# Epoch 00018: saving model to best_model.h5

# %%
loss, acc = model.evaluate(X_test, y_test, verbose=2)
# Out:
# 18/18 - 0s - loss: 0.0659 - accuracy: 0.9800

# %%
model.save("cropmodel.h5")
print("model saved")
# Out:
# model saved

# %%
targets.values()
# Out:
# dict_values(['apple', 'banana', 'blackgram', 'chickpea', 'coconut', 'coffee', 'cotton', 'grapes', 'jute', 'kidneybeans', 'lentil', 'maize', 'mango', 'mothbeans', 'mungbean', 'muskmelon', 'orange', 'papaya', 'pigeonpeas', 'pomegranate', 'rice', 'watermelon'])
